# %%
import pandas as pd
import pyodbc #for ms SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#                                               0.0/11.9 MB ? eta -:--:--
#                                               0.1/11.9 MB 3.2 MB/s eta 0:00:04
#                                               0.2/11.9 MB 3.0 MB/s eta 0:00:04
#      -                                        0.3/11.9 MB 2.5 MB/s eta 0:00:05
#      -                                        0.5/11.9 MB 2.9 MB/s eta 0:00:04
#      --                                       0.6/11.9 MB 2.8 MB/s eta 0:00:05
#      --                                       0.8/11.9 MB 2.9 MB/s eta 0:00:04
#      ---                                      0.9/11.9 MB 2.9 MB/s eta 0:00:04
#      ---                                      1.1/11.9 MB 3.0 MB/s eta 0:00:04
#      ----                                     1.2/11.9 MB 3.0 MB/s eta 0:00:04
#      ----                                     1.4/11.9 MB 3.0 MB/s eta 0:00:04
#      -----                                    1.5/11.9 MB 3.0 MB/s eta 0:00:04
# ...

# %%
# import mysql.connector as mc #for mysql

# %%
conn = pyodbc.connect('Driver={SQL Server Native Client 11.0};'
                    'Server=DESKTOP-J0G5LG8;'
                    'Database=InfoData;'
                    'Trusted_Connection=yes;'
                        )
show = conn.cursor()

# %%
df = pd.read_sql_query('select * from BookList',conn) #can write query as per requirement
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5896\705656723.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('select * from BookList',conn)
#     ID         Title       Message     City
# 0    1   Harry pottr  Amazing Book     pune
# 1    2           ABC      Good one  nhavare
# 2    3   lawOfSucess     Inspiring     pune
# 3    3   lawOfSucess     Inspiring     pune
# 4    4  IndianPolity     Marvolous    Delhi
# 5    5      Spectrum   understable  Solapur
# 6    6   Environment          Easy   Mumbai
# 7    3   lawOfSucess     Inspiring     pune
# 8    4  IndianPolity     Marvolous    Delhi
# 9    5      Spectrum   understable  Solapur
# 10   6   Environment          Easy   Mumbai
# 11   3   lawOfSucess     Inspiring     pune
# 12   4  IndianPolity     Marvolous    Delhi
# ...
